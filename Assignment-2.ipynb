# %%
## Q1 Create a string s containing your full name. Print the string.

# %%
s = "SM Hamza Hussain"
print(s)
# Out:
# SM Hamza Hussain

# %%
## Q2 Create a string s with a sentence of your choice and print its length.

# %%
s = "Python is my first programming choice"
print(len(s))
# Out:
# 37

# %%
## Q3 Assign a string to a variable and check its data type using Python

# %%
a = "I love python"
type(a)
# Out:
# str

# %%
## Q4 Create a variable word with the value "Python" and print the first character.

# %%
word = "Python"
print(word[0])
# Out:
# P

# %%
## Q5 Create a variable course with the value "Python" and print the character at index 3.

# %%
course = "Python"
print(course[3])
# Out:
# h

# %%
## Q6 Create a variable framework with the value "TensorFlow" and print the character at negative index -4.

# %%
framework = "Tensorflow"
print(framework[-4])
# Out:
# f

# %%
## Q7 Create a variable fruit with the value "Apple". Convert the string to uppercase and print it.

# %%
fruit = "Apple"
print(fruit.upper())
# Out:
# APPLE

# %%
## Q8 Create a variable city with the value "Karachi". Convert the string to lowercase and print it.

# %%
city = "Karachi"
print(city.lower())
# Out:
# karachi

# %%
## Q9 Create a variable framework with the value "Django". Check if the string starts with "D" and print True or False.

# %%
framework = "Django"
print(framework.startswith("D"))
# Out:
# True

# %%
## Q10  Create a variable subject with the value "Mathematics". Check if all characters are alphabetic and print True or False.

# %%
subject = "Mathematics"
print(subject.isalpha())
# Out:
# True

# %%
## Q11 Ask the user to enter their email in any format.
## and then Convert it into lowercase.

# %%
Email = input("Enter Your Email Here: ").lower()
print(Email)
# Out:
# Enter Your Email Here:  SMHAMZA@GMAIL.COM
# smhamza@gmail.com

# %%
# Q12 check if a number is even or odd where number is taken as input

# %%
number = int(input("Enter a number here: "))
if number % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter a number here:  6
# Number is Even

# %%
number = int(input("Enter a number here: "))
if number % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter a number here:  91
# Number is Odd

# %%
# Q13 User se number lo:

# agar number > 0 → "Positive"
# warna → "Negative"

# %%
number = int(input("Enter a number here: "))
if number>=0:
    print("Positive")
else:
    print("Negative")

# %%
# Q14  User se password lo:

# agar "python123" hai → "Access Granted"
# warna → "Access Denied"

# %%
password = input("Enter your password: ")

if password == "python123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your password:  pyhton000
# Access Denied

# %%
password = input("Enter your password: ")

if password == "python123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your password:  python123
# Access Granted

# %%
# Q15 User se temperature lo:

# agar > 30 → "Hot"
# warna → "Normal"

# %%
temperature = int(input("Enter temperature "))
if temperature > 30:
    print("Hot")
else:
    print("Normal")
# Out:
# Enter temperature  28
# Normal

# %%
temperature = int(input("Enter temperature "))
if temperature > 30:
    print("Hot")
else:
    print("Normal")
# Out:
# Enter temperature  33
# Hot

# %%
# Q16 User se naam lo:
# agar naam "Ali" hai → "Welcome Ali"
# warna → "Welcome User"

# %%
name = input("Enter your name")
if name == "Ali":
    print("Welcome Ali")
else:
    print("Welcome User")
# Out:
# Enter your name Ali
# Welcome Ali

# %%
name = input("Enter your name")
if name == "Ali":
    print("Welcome Ali")
else:
    print("Welcome User")
# Out:
# Enter your name Ahsan
# Welcome User

# %%
# Q17 User se marks lo aur grade do:

# 90+ → A
# 80+ → B
# 70+ → C
# 60+ → D
# warna → Fail

# %%
marks = int(input("Enter Your Marks: "))
if marks > 90:
    print("Grade-A")
elif marks > 80:
    print("Grade-B")
elif marks > 70:
    print("Grade-C")
elif marks >= 60:
    print("Grade-D")
else:
    print("Fail")
# Out:
# Enter Your Marks:  91
# Grade-A

# %%
marks = int(input("Enter Your Marks: "))
if marks > 90:
    print("Grade-A")
elif marks > 80:
    print("Grade-B")
elif marks > 70:
    print("Grade-C")
elif marks >= 60:
    print("Grade-D")
else:
    print("Fail")
# Out:
# Enter Your Marks:  87
# Grade-B

# %%
marks = int(input("Enter Your Marks: "))
if marks > 90:
    print("Grade-A")
elif marks > 80:
    print("Grade-B")
elif marks > 70:
    print("Grade-C")
elif marks >= 60:
    print("Grade-D")
else:
    print("Fail")
# Out:
# Enter Your Marks:  74
# Grade-C

# %%
marks = int(input("Enter Your Marks: "))
if marks > 90:
    print("Grade-A")
elif marks > 80:
    print("Grade-B")
elif marks > 70:
    print("Grade-C")
elif marks >= 60:
    print("Grade-D")
else:
    print("Fail")
# Out:
# Enter Your Marks:  63
# Grade-D

# %%
marks = int(input("Enter Your Marks: "))
if marks > 90:
    print("Grade-A")
elif marks > 80:
    print("Grade-B")
elif marks > 70:
    print("Grade-C")
elif marks >= 60:
    print("Grade-D")
else:
    print("Fail")
# Out:
# Enter Your Marks:  42
# Fail

# %%
# Q18 User se day number (1–7) lo:


# 1 → Monday
# 2 → Tuesday
## ...
# 7 → Sunday

# %%
day = int(input("Enter day number (1-7): "))

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
    print("Sunday")
else:
    print("Invalid input")
# Out:
# Enter day number (1-7):  1
# Monday

# %%
day = int(input("Enter day number (1-7): "))

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
    print("Sunday")
else:
    print("Invalid input")
# Out:
# Enter day number (1-7):  5
# Friday

# %%
day = int(input("Enter day number (1-7): "))

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
    print("Sunday")
else:
    print("Invalid input")
# Out:
# Enter day number (1-7):  9
# Invalid input

# %%
# Q19 User se month number lo:

# 12,1,2 → Winter
# 3,4,5 → Spring
# 6,7,8 → Summer
# warna → Autumn

# %%
month = int(input("Enter Month Number: "))
if month in [12,1,2]:
     print("Winter")
elif month in [3,4,5]:
     print("Spring")
elif month in [6,7,8]:
     print("Summer")
else:
     print("Autumn")
# Out:
# Enter Month Number:  5
# Spring

# %%
# Q20 User se 2 numbers lo:

# pehla > dusra → "First is greater"
# pehla < dusra → "Second is greater"
# warna → "Both equal"

# %%
num1 = int(input("Enter Your Number Here: "))
num2 = int(input("Enter Your Number Here: "))
if num1>num2:
    print("First is greater")
elif num1<num2:
    print("Second is Greater")
else:
    print("Both Equal")
# Out:
# Enter Your Number Here:  6
# Enter Your Number Here:  4
# First is greater

# %%
num1 = int(input("Enter Your Number Here: "))
num2 = int(input("Enter Your Number Here: "))
if num1>num2:
    print("First is greater")
elif num1<num2:
    print("Second is Greater")
else:
    print("Both Equal")
# Out:
# Enter Your Number Here:  9
# Enter Your Number Here:  15
# Second is Greater

# %%
num1 = int(input("Enter Your Number Here: "))
num2 = int(input("Enter Your Number Here: "))
if num1>num2:
    print("First is greater")
elif num1<num2:
    print("Second is Greater")
else:
    print("Both Equal")
# Out:
# Enter Your Number Here:  5
# Enter Your Number Here:  5
# Both Equal

# %%
# Q21 Simple calculator:
# User se operator lo (+, -, *, /):

# → addition
# → subtraction
# → multiplication
# / → division
# warna → "Invalid operator"

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "*":
    print("Result:", num1 * num2)
elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Enter first number:  9
# Enter second number:  5
# Enter operator (+, -, *, /):  -
# Result: 4.0

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "*":
    print("Result:", num1 * num2)
elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Enter first number:  8
# Enter second number:  8
# Enter operator (+, -, *, /):  *
# Result: 64.0
